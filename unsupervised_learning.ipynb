# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from data_preprocessing import *
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import xgboost as xg 
from sklearn.metrics import mean_squared_error as MSE

# %%
kmeans = KMeans(n_clusters = 5, random_state = 0, n_init='auto')
kmeans.fit(X_train_copy)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
silhouette_score(X_train_copy, kmeans.labels_, metric='euclidean')
# Out:
# 0.4111956001223131

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123) 


xgb_r.fit(X_train_copy, y_train_copy) 


pred = xgb_r.predict(X_test_copy) 


rmse = np.sqrt(MSE(y_test_copy, pred)) 
print("RMSE : % f" %(rmse))
# Out:
# c:\Users\ErikaLD\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:34:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 7
#       1 xgb_r = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123)
#       4 xgb_r.fit(X_train_copy, y_train_copy)
# ----> 7 pred = xgb_r.predict(X_test_copy)
#      10 rmse = np.sqrt(MSE(y_test_copy, pred))
#      11 print("RMSE : % f" %(rmse))
#
# File c:\Users\ErikaLD\AppData\Local\anaconda3\Lib\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File c:\Users\ErikaLD\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File c:\Users\ErikaLD\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['Male', 'Animal', 'Friends', 'Family', 'Dead&Imaginary'] ['Gender', 'Male', 'Animal', 'Friends', 'Family', 'Dead&Imaginary', 'Aggression/Friendliness', 'A/CIndex', 'F/CIndex', 'S/CIndex']
# training data did not have the following fields: A/CIndex, Gender, F/CIndex, Aggression/Friendliness, S/CIndex

# %%
X_train_copy.head(5)
